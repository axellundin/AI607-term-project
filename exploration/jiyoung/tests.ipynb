# %%
import pandas as pd

# %%
import pandas as pd


train = pd.read_csv(
    '../../data/task2_train.tsv',
    names=['user', 'item', 'interaction'],
    sep='\t'
)


val = pd.read_csv(
    '../../data/task2_val_queries.tsv',
    names=['user'],
    sep='\t'
)

val_answers = pd.read_csv(
    '../../data/task2_val_answers.tsv',
    names=['user', 'item','interaction'],
    sep='\t'
)

# %%
print(train.head())
print(val.head())
print(val_answers.head())
# Out:
#     user  item  interaction
# 0  15684  3591            2
# 1  15684   874            3
# 2  15684   908            3
# 3  15684  1110            2
# 4  15684  2017            3
#     user
# 0  10859
# 1  10874
# 2  10880
# 3  10882
# 4  10883
#     user  item  interaction
# 0  10859    41            1
# 1  10859   717            1
# 2  10859   987            1
# 3  10859  1054            1
# 4  10859  1380            1
